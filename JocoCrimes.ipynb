# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.cluster import KMeans

# %%
# Read in the CSV file and create the Pandas Dataframe
joco_crimes = pd.read_csv(Path("./Resources/merged_data.csv"))
 
# Review the DataFrame
joco_crimes.head()
# Out:
#           ID EventType     Class  \
# 0  D23003080    crimes  Property
# 1  D23003074    crimes   Society
# 2  D23003087    crimes   Society
# 3  D23003064    crimes   Society
# 4  D23003086    crimes   Society
#
#                                     UCRDescription  \
# 0                           Counterfeiting/Forgery
# 1                            Weapon Law Violations
# 2                               All Other Offenses
# 3  Drug/Narcotic Offenses-Drug/Narcotic Violations
# 4                               All Other Offenses
#
#                                  IncidentDescription TheftDescription  \
# 0  FORGERY; POSSESS WITH INTENT TO DISTRIBUTE WRI...              NaN
# 1           UNLAWFUL DISCHARGE OF FIREARMS (10.10.5)              NaN
# 2                      PROBATION VIOLATION (22-3716)              NaN
# 3          POSSESSION OF MARIJUANA (21-5706.b3.c3.A)              NaN
# 4                      PROBATION VIOLATION (22-3716)              NaN
#
#                   Location                           PremiseDescription  \
# 0   100 BLOCK N KANSAS AVE                                Jail / Prison
# 1  24800 BLOCK W 129TH TER  Single Residence (includes attached garage)
# 2   100 BLOCK N KANSAS AVE                                Jail / Prison
# 3                W K10 HWY                                      Highway
# 4   100 BLOCK N KANSAS AVE                                Jail / Prison
#
#            APID UCRCode  ... ReptTime InactivityDescription  HitRun  \
# 0  2.003041e+17     250  ...      832                   NaN     NaN
# 1  2.003023e+17     520  ...     1948                   NaN     NaN
# 2  2.003041e+17     90Z  ...     1440                   NaN     NaN
# 3           NaN     35A  ...     1712                   NaN     NaN
# 4  2.003041e+17     90Z  ...     1729                   NaN     NaN
#
#            Y          X  Name  Compliant  Race  Sex  DOB
# 0  38.883172 -94.821215   NaN        NaN   NaN  NaN  NaN
# 1  38.893987 -94.873529   NaN        NaN   NaN  NaN  NaN
# 2  38.883172 -94.821215   NaN        NaN   NaN  NaN  NaN
# 3  38.960213 -94.955056   NaN        NaN   NaN  NaN  NaN
# 4  38.883172 -94.821215   NaN        NaN   NaN  NaN  NaN
#
# [5 rows x 22 columns]

# %%
joco_crimes.shape
# Out:
# (2997, 22)

# %%
# Checking the null values and the Datatype
joco_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2997 entries, 0 to 2996
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     2997 non-null   object
#  1   EventType              2997 non-null   object
#  2   Class                  2039 non-null   object
#  3   UCRDescription         2039 non-null   object
#  4   IncidentDescription    2996 non-null   object
#  5   TheftDescription       95 non-null     object
#  6   Location               2997 non-null   object
#  7   PremiseDescription     2036 non-null   object
#  8   APID                   1945 non-null   float64
#  9   UCRCode                2996 non-null   object
#  10  Agency                 2997 non-null   object
#  11  ReptDate               2997 non-null   object
#  12  ReptTime               2997 non-null   int64
#  13  InactivityDescription  0 non-null      float64
#  14  HitRun                 0 non-null      float64
#  15  Y                      2997 non-null   float64
#  16  X                      2997 non-null   float64
#  17  Name                   0 non-null      float64
#  18  Compliant              0 non-null      float64
#  19  Race                   0 non-null      float64
#  20  Sex                    0 non-null      float64
#  21  DOB                    0 non-null      float64
# dtypes: float64(10), int64(1), object(11)
# memory usage: 515.2+ KB

# %%
# Droping all the columns that are empty (0 non-null)
joco_crimes_df = joco_crimes.drop(columns=["Name", "Compliant","Race","Sex","DOB",\
                                           "InactivityDescription", "HitRun","APID",\
                                           "TheftDescription","Agency","EventType"])

# %%
# Droping the rows with null values 
joco_crimes_df = joco_crimes_df.dropna()
joco_crimes_df.tail()
# Out:
#              ID    Class      UCRDescription  \
# 2987  D22002293  Society  All Other Offenses
# 2988  D22002294  Society  All Other Offenses
# 2989  D22002282  Society  All Other Offenses
# 2990  D22002250  Society  All Other Offenses
# 2991  D22002280  Society  All Other Offenses
#
#                                     IncidentDescription            Location  \
# 2987                      FAILURE TO APPEAR (21-5915.a)  700 BLOCK N 7TH ST
# 2988                      FAILURE TO APPEAR (21-5915.a)  700 BLOCK N 7TH ST
# 2989                      FAILURE TO APPEAR (21-5915.a)  700 BLOCK N 7TH ST
# 2990  Flee or attempt to elude LEO by engaging in re...          W 197TH ST
# 2991                       RACING ON HIGHWAYS (08-1565)          W 175TH ST
#
#      PremiseDescription UCRCode    ReptDate  ReptTime          Y          X
# 2987      Jail / Prison     90Z  2022-06-28      1120  39.024753 -94.640914
# 2988      Jail / Prison     90Z  2022-06-28      1120  39.024753 -94.640914
# 2989      Jail / Prison     90Z  2022-06-28      1017  38.615399 -94.684003
# 2990        City Street     90Z  2022-06-28       441  38.771475 -94.670614
# 2991            Highway     90Z  2022-06-28        28  38.810943 -94.821198

# %%
joco_crimes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2032 entries, 0 to 2991
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2032 non-null   object
#  1   Class                2032 non-null   object
#  2   UCRDescription       2032 non-null   object
#  3   IncidentDescription  2032 non-null   object
#  4   Location             2032 non-null   object
#  5   PremiseDescription   2032 non-null   object
#  6   UCRCode              2032 non-null   object
#  7   ReptDate             2032 non-null   object
#  8   ReptTime             2032 non-null   int64
#  9   Y                    2032 non-null   float64
#  10  X                    2032 non-null   float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 190.5+ KB

# %%
# Counting the values for the UCRDescription column
value_cunts = joco_crimes_df.UCRDescription.value_counts()
value_cunts
# Out:
# All Other Offenses                                         906
# Drug/Narcotic Offenses-Drug/Narcotic Violations            352
# Driving Under the Influence                                195
# Assault-Simple Assault                                      91
# Destruction/Damage/Vandalism of Property                    90
# Larceny/Theft Offenses                                      83
# Fraud Offenses-False Pretenses/Swindle/Conf. Game           52
# Assault-Intimidation                                        45
# Liquor Law Violations                                       45
# Drug/Narcotic Offenses-Drug Equipment Violations            43
# Trespass of Real Property                                   30
# Assault-Aggravated Assault                                  16
# Burglary/Breaking & Entering                                15
# Counterfeiting/Forgery                                       9
# Sex Offenses Forcible-Forcible Fondling                      8
# Disorderly Conduct                                           6
# Sex Offenses Forcible-Forcible Rape                          6
# Bad Checks                                                   6
# Weapon Law Violations                                        5
# Fraud Offenses-Credit Card/Automatic Teller Mach. Fraud      5
# Stolen Property Offenses                                     4
# Motor Vehicle Theft                                          4
# Pornography/Obscene Material                                 3
# Arson                                                        3
# Fraud Offenses-Impersonation                                 2
# Extortion/Blackmail                                          2
# Kidnapping/Abduction                                         2
# Drunkenness                                                  1
# Sex Offenses Nonforcible-Statutory Rape                      1
# Family Offenses Nonviolent                                   1
# Embezzlement                                                 1
# Name: UCRDescription, dtype: int64

# %%
# We're filtering by rows with value_counts >= 30
undroped = joco_crimes_df.UCRDescription.isin(value_cunts[value_cunts >= 30].index)

# %%
# Aply a boolean indexing 
joco_crimes_df_filtered = joco_crimes_df[undroped]

# %%
joco_crimes_df_filtered.head()
# Out:
#           ID    Class                                   UCRDescription  \
# 2  D23003087  Society                               All Other Offenses
# 3  D23003064  Society  Drug/Narcotic Offenses-Drug/Narcotic Violations
# 4  D23003086  Society                               All Other Offenses
# 5  D23003085  Society                               All Other Offenses
# 8  D23003053  Society  Drug/Narcotic Offenses-Drug/Narcotic Violations
#
#                          IncidentDescription                Location  \
# 2              PROBATION VIOLATION (22-3716)  100 BLOCK N KANSAS AVE
# 3  POSSESSION OF MARIJUANA (21-5706.b3.c3.A)               W K10 HWY
# 4              PROBATION VIOLATION (22-3716)  100 BLOCK N KANSAS AVE
# 5              FAILURE TO APPEAR (21-5915.a)     6600 BLOCK CRAIG RD
# 8  POSSESSION OF MARIJUANA (21-5706.b3.c3.A)               E K10 HWY
#
#                             PremiseDescription UCRCode    ReptDate  ReptTime  \
# 2                                Jail / Prison     90Z  2023-09-03      1440
# 3                                      Highway     35A  2023-09-02      1712
# 4                                Jail / Prison     90Z  2023-09-01      1729
# 5  Single Residence (includes attached garage)     90Z  2023-09-01      1459
# 8                                      Highway     35A  2023-09-01      1319
#
#            Y          X
# 2  38.883172 -94.821215
# 3  38.960213 -94.955056
# 4  38.883172 -94.821215
# 5  39.009349 -94.678366
# 8  38.947513 -94.885671

# %%
joco_crimes_df_filtered.UCRDescription.value_counts()
# Out:
# All Other Offenses                                   906
# Drug/Narcotic Offenses-Drug/Narcotic Violations      352
# Driving Under the Influence                          195
# Assault-Simple Assault                                91
# Destruction/Damage/Vandalism of Property              90
# Larceny/Theft Offenses                                83
# Fraud Offenses-False Pretenses/Swindle/Conf. Game     52
# Assault-Intimidation                                  45
# Liquor Law Violations                                 45
# Drug/Narcotic Offenses-Drug Equipment Violations      43
# Trespass of Real Property                             30
# Name: UCRDescription, dtype: int64

# %%
joco_crimes_df_filtered.UCRDescription.unique()
# Out:
# array(['All Other Offenses',
#        'Drug/Narcotic Offenses-Drug/Narcotic Violations',
#        'Larceny/Theft Offenses', 'Trespass of Real Property',
#        'Fraud Offenses-False Pretenses/Swindle/Conf. Game',
#        'Drug/Narcotic Offenses-Drug Equipment Violations',
#        'Assault-Intimidation', 'Driving Under the Influence',
#        'Assault-Simple Assault', 'Liquor Law Violations',
#        'Destruction/Damage/Vandalism of Property'], dtype=object)

# %%
# Create a mapping for categories to be combined and their new names

category_mapping = {
    'All Other Offenses': 'Other offences',
    'Drug/Narcotic Offenses-Drug/Narcotic Violations' : 'Drug',
    'Larceny/Theft Offenses' : 'Theft',
    'Trespass of Real Property' : 'Property',
    'Fraud Offenses-False Pretenses/Swindle/Conf. Game' : 'Fraud',
    'Drug/Narcotic Offenses-Drug Equipment Violations' : 'Drug',
    'Assault-Intimidation' : 'Assault',
    'Driving Under the Influence' : 'DUI',
    'Assault-Simple Assault' : 'Assault', 
    'Liquor Law Violations' : 'Liquor',
    'Destruction/Damage/Vandalism of Property': 'Property'
}

# %%
# Apply the mapping to create a new 'combined_category' column
joco_crimes_df_filtered['combined_category'] = joco_crimes_df_filtered.UCRDescription.map(category_mapping)
# Out:
# /var/folders/cg/s6p6vc1d3hg1gs1nhcf0cyym0000gn/T/ipykernel_958/2465236208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joco_crimes_df_filtered['combined_category'] = joco_crimes_df_filtered.UCRDescription.map(category_mapping)

# %%
joco_crimes_df_filtered.head()
# Out:
#           ID    Class                                   UCRDescription  \
# 2  D23003087  Society                               All Other Offenses
# 3  D23003064  Society  Drug/Narcotic Offenses-Drug/Narcotic Violations
# 4  D23003086  Society                               All Other Offenses
# 5  D23003085  Society                               All Other Offenses
# 8  D23003053  Society  Drug/Narcotic Offenses-Drug/Narcotic Violations
#
#                          IncidentDescription                Location  \
# 2              PROBATION VIOLATION (22-3716)  100 BLOCK N KANSAS AVE
# 3  POSSESSION OF MARIJUANA (21-5706.b3.c3.A)               W K10 HWY
# 4              PROBATION VIOLATION (22-3716)  100 BLOCK N KANSAS AVE
# 5              FAILURE TO APPEAR (21-5915.a)     6600 BLOCK CRAIG RD
# 8  POSSESSION OF MARIJUANA (21-5706.b3.c3.A)               E K10 HWY
#
#                             PremiseDescription UCRCode    ReptDate  ReptTime  \
# 2                                Jail / Prison     90Z  2023-09-03      1440
# 3                                      Highway     35A  2023-09-02      1712
# 4                                Jail / Prison     90Z  2023-09-01      1729
# 5  Single Residence (includes attached garage)     90Z  2023-09-01      1459
# 8                                      Highway     35A  2023-09-01      1319
#
#            Y          X combined_category
# 2  38.883172 -94.821215    Other offences
# 3  38.960213 -94.955056              Drug
# 4  38.883172 -94.821215    Other offences
# 5  39.009349 -94.678366    Other offences
# 8  38.947513 -94.885671              Drug
