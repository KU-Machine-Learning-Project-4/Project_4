# %%
import pandas as pd
from pathlib import Path
from sklearn.cluster import KMeans
import geopy
from geopy.geocoders import Nominatim
import time

# %%
# Read in the CSV file and create the Pandas Dataframe
joco_crimes = pd.read_csv(Path("./Resources/merged_data.csv"))
 
# Review the DataFrame
joco_crimes.head()
# Out:
#           ID EventType     Class  \
# 0  D23003080    crimes  Property
# 1  D23003074    crimes   Society
# 2  D23003087    crimes   Society
# 3  D23003064    crimes   Society
# 4  D23003086    crimes   Society
#
#                                     UCRDescription  \
# 0                           Counterfeiting/Forgery
# 1                            Weapon Law Violations
# 2                               All Other Offenses
# 3  Drug/Narcotic Offenses-Drug/Narcotic Violations
# 4                               All Other Offenses
#
#                                  IncidentDescription TheftDescription  \
# 0  FORGERY; POSSESS WITH INTENT TO DISTRIBUTE WRI...              NaN
# 1           UNLAWFUL DISCHARGE OF FIREARMS (10.10.5)              NaN
# 2                      PROBATION VIOLATION (22-3716)              NaN
# 3          POSSESSION OF MARIJUANA (21-5706.b3.c3.A)              NaN
# 4                      PROBATION VIOLATION (22-3716)              NaN
#
# ...

# %%
joco_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2997 entries, 0 to 2996
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     2997 non-null   object
#  1   EventType              2997 non-null   object
#  2   Class                  2039 non-null   object
#  3   UCRDescription         2039 non-null   object
#  4   IncidentDescription    2996 non-null   object
#  5   TheftDescription       95 non-null     object
#  6   Location               2997 non-null   object
#  7   PremiseDescription     2036 non-null   object
#  8   APID                   1945 non-null   float64
#  9   UCRCode                2996 non-null   object
#  10  Agency                 2997 non-null   object
#  11  ReptDate               2997 non-null   object
#  12  ReptTime               2997 non-null   int64
#  13  InactivityDescription  0 non-null      float64
# ...

# %%
joco_crimes_df = joco_crimes.drop(columns=["Name", "Compliant","Race","Sex","DOB",\
                                           "InactivityDescription", "HitRun",\
                                           "TheftDescription","Agency","EventType"])

joco_crimes_df.head()
# Out:
#           ID     Class                                   UCRDescription  \
# 0  D23003080  Property                           Counterfeiting/Forgery
# 1  D23003074   Society                            Weapon Law Violations
# 2  D23003087   Society                               All Other Offenses
# 3  D23003064   Society  Drug/Narcotic Offenses-Drug/Narcotic Violations
# 4  D23003086   Society                               All Other Offenses
#
#                                  IncidentDescription                 Location  \
# 0  FORGERY; POSSESS WITH INTENT TO DISTRIBUTE WRI...   100 BLOCK N KANSAS AVE
# 1           UNLAWFUL DISCHARGE OF FIREARMS (10.10.5)  24800 BLOCK W 129TH TER
# 2                      PROBATION VIOLATION (22-3716)   100 BLOCK N KANSAS AVE
# 3          POSSESSION OF MARIJUANA (21-5706.b3.c3.A)                W K10 HWY
# 4                      PROBATION VIOLATION (22-3716)   100 BLOCK N KANSAS AVE
#
# ...

# %%
joco_crimes_df.to_csv('joco_crimes_1.csv', index=False)

# %%
import csv
import time
with open('joco_crimes_1.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        location = geolocator.reverse((row["Y"],row["X"]))
        print(row["Y"],row["X"], location.raw['address']['postcode'])
        time.sleep(2)
# Out:
# 38.883172 -94.821215 66061
# 38.893987 -94.873529 66061
# 38.883172 -94.821215 66061
# 38.960213 -94.955056 66018
# 38.883172 -94.821215 66061
# 39.009349 -94.678366 66202
# 38.883172 -94.821215 66061
# 38.882017 -94.820666 66061
# 38.947513 -94.885671 66227
# 38.879738 -94.82583 66061
# 38.883172 -94.821215 66061
# 38.912792 -94.771334 66214
# 38.883172 -94.821215 66061
# 39.024753 -94.640914 66217
# 38.883172 -94.821215 66061
# 38.883737 -94.834603 66061
# 38.884509 -94.808272 66061
# 38.883172 -94.821215 66061
# 38.914665 -94.79935 66061
# 38.883172 -94.821215 66061
# 38.883172 -94.821215 66061
# 38.883172 -94.821215 66061
# 38.883172 -94.821215 66061
# 39.018392 -94.660429 66202
# 39.018392 -94.660429 66202
# 38.929967 -94.728369 66210
# 38.929967 -94.728369 66210
# 38.976249 -94.95413 66018
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 7
# ...

# %%
geolocator = geopy.Nominatim(user_agent='joco_custom')

# %%
location = geolocator.reverse((df[lat_field], df[lon_field]))

# %%
joco_crimes_df["Class"].value_counts()
# Out:
# Society     1558
# Property     244
# Person       237
# Name: Class, dtype: int64

# %%
def get_zipcode(df, geolocator, lat_field, lon_field):
    location = geolocator.reverse((df[lat_field], df[lon_field]))
    try: 
        output = location.raw['address']['postcode']
    except: 
        output = "none"
    time.sleep(1.5)
    return output

# %%
just10_df = joco_crimes_df.head(10)

# %%
#def get_zipcode(joco_crimes_df, geolocator, lat_field, lon_field):
    #location = geolocator.reverse((joco_crimes_df["Y"], joco_crimes_df["X"]))
    #return location.raw['address']['postcode']

geolocator = geopy.Nominatim(user_agent='joco_custom')

zipcodes = joco_crimes_df.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='Y', lon_field='X')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# ...

# %%
x = geolocator.reverse((38.883172, -94.821215))
x
# Out:
# Location(Johnson County Adult Detention Center, North Kansas Avenue, Olathe, Johnson County, Kansas, 66061, United States, (38.8831308, -94.8210084, 0.0))

# %%
zipcodes
# Out:
# 0    66061
# 1    66061
# 2    66061
# 3    66018
# 4    66061
# 5    66202
# 6    66061
# 7    66061
# 8    66227
# 9    66061
# dtype: object

# %%
x.raw['address']['postcode']
# Out:
# '66061'

# %%
joco_crimes_df['Zipcode'] = zipcodes

# %%
joco_crimes_df
# Out:
#                ID     Class                                   UCRDescription  \
# 0       D23003080  Property                           Counterfeiting/Forgery
# 1       D23003074   Society                            Weapon Law Violations
# 2       D23003087   Society                               All Other Offenses
# 3       D23003064   Society  Drug/Narcotic Offenses-Drug/Narcotic Violations
# 4       D23003086   Society                               All Other Offenses
# ...           ...       ...                                              ...
# 2992    D22002263       NaN                                              NaN
# 2993    D22002261       NaN                                              NaN
# 2994  DSO22202377       NaN                                              NaN
# 2995    D22002260       NaN                                              NaN
# 2996    D22002259       NaN                                              NaN
#
# ...

# %%
joco_crimes_df.to_csv('joco_crimes.csv', index=False)

# %%
joco_crimes_df
# Out:
#                ID     Class                                   UCRDescription  \
# 0       D23003080  Property                           Counterfeiting/Forgery
# 1       D23003074   Society                            Weapon Law Violations
# 2       D23003087   Society                               All Other Offenses
# 3       D23003064   Society  Drug/Narcotic Offenses-Drug/Narcotic Violations
# 4       D23003086   Society                               All Other Offenses
# ...           ...       ...                                              ...
# 2992    D22002263       NaN                                              NaN
# 2993    D22002261       NaN                                              NaN
# 2994  DSO22202377       NaN                                              NaN
# 2995    D22002260       NaN                                              NaN
# 2996    D22002259       NaN                                              NaN
#
# ...
